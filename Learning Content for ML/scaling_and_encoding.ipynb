# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import sklearn as sk

# %%
df = sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df['fare'].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: fare, dtype: float64

# %%
df['fare category'] = pd.cut(df['fare'], bins=[0, 10, 20, 30, 40, 50], labels=['very low', 'low', 'medium', 'high', 'very high'])

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone fare category
# 0    man        True  NaN  Southampton    no  False      very low
# 1  woman       False    C    Cherbourg   yes  False           NaN
# 2  woman       False  NaN  Southampton   yes   True      very low
# 3  woman       False    C  Southampton   yes  False           NaN
# 4    man        True  NaN  Southampton    no   True      very low

# %%
pd.cut(df['fare'], bins=5).value_counts().sort_index()
# Out:
# fare
# (-0.512, 102.466]     838
# (102.466, 204.932]     33
# (204.932, 307.398]     17
# (307.398, 409.863]      0
# (409.863, 512.329]      3
# Name: count, dtype: int64

# %%
ages = pd.Series([3,15,27,18,40,68])
bins = [0,18,35,60,120]
labels = ['child','young','adult','senior']
pd.cut(ages, bins=bins, labels=labels, right=False)
# Out:
# 0     child
# 1     child
# 2     young
# 3     young
# 4     adult
# 5    senior
# dtype: category
# Categories (4, object): ['child' < 'young' < 'adult' < 'senior']
