# %%
import yfinance as yf

data = yf.download("SBIN.NS", start="2020-01-01", end="2025-12-25")
print(data.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open    Volume
# Ticker         SBIN.NS     SBIN.NS     SBIN.NS     SBIN.NS   SBIN.NS
# Date
# 2020-01-01  308.602600  309.986675  306.480335  308.833279  17379320
# 2020-01-02  313.077728  313.585239  307.587581  308.648700  20324236
# 2020-01-03  307.910553  311.832099  306.341923  311.832099  21853208
# 2020-01-06  294.346619  306.065132  293.147098  306.065132  35645325
# 2020-01-07  293.792999  301.728369  291.024849  299.375452  50966826

# %%
data['Close']['SBIN.NS'].plot()
# Out:
# <Axes: xlabel='Date'>
