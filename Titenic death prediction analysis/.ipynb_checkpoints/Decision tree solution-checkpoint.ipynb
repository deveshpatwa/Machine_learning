# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("titanic_data.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
sns.histplot(data=df,x='Age')
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
df['Age'].mean(),df['Age'].median()
# Out:
# (np.float64(29.69911764705882), np.float64(28.0))

# %%
sns.boxplot(x=df['Age'])
# Out:
# <Axes: xlabel='Age'>

# %%
print(df.columns)
df.drop(columns=['Name','Ticket'])
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin  \
# 0              1         0       3    male  22.0      1      0   7.2500   NaN
# 1              2         1       1  female  38.0      1      0  71.2833   C85
# 2              3         1       3  female  26.0      0      0   7.9250   NaN
# 3              4         1       1  female  35.0      1      0  53.1000  C123
# 4              5         0       3    male  35.0      0      0   8.0500   NaN
# ..           ...       ...     ...     ...   ...    ...    ...      ...   ...
# 886          887         0       2    male  27.0      0      0  13.0000   NaN
# 887          888         1       1  female  19.0      0      0  30.0000   B42
# 888          889         0       3  female   NaN      1      2  23.4500   NaN
# ...

# %%
print("total unique values -",df['Cabin'].nunique())
df['Cabin'].unique()
# Out:
# total unique values - 147
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
df['Cabin'] = df['Cabin'].fillna("unknown")

# %%
df['cabin code']= df['Cabin'].apply(lambda x:x[0])

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'cabin code'],
#       dtype='object')

# %%
df= df.drop(columns=['Name','Cabin','Ticket'])

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0            1         0       3    male  22.0      1      0   7.2500
# 1            2         1       1  female  38.0      1      0  71.2833
# 2            3         1       3  female  26.0      0      0   7.9250
# 3            4         1       1  female  35.0      1      0  53.1000
# 4            5         0       3    male  35.0      0      0   8.0500
#
#   Embarked cabin code
# 0        S          u
# 1        C          C
# 2        S          u
# 3        S          C
# 4        S          u

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Sex          891 non-null    object
#  4   Age          714 non-null    float64
#  5   SibSp        891 non-null    int64
#  6   Parch        891 non-null    int64
#  7   Fare         891 non-null    float64
#  8   Embarked     889 non-null    object
#  9   cabin code   891 non-null    object
# dtypes: float64(2), int64(5), object(3)
# memory usage: 69.7+ KB

# %% [raw]
# def finding_cabin_name(name):
#     cabin_name = ""
#     cabin_number = ""
#     for i in name:
#         if i.isdigit()== False:
#             cabin_name +=i
#         else:
#             cabin_number += i
#     return cabin_name
#
# def finding_cabin_number(name):
#     cabin_name = ""
#     cabin_number = ""
#     for i in name:
#         if i.isdigit()== False:
#             cabin_name +=i
#         else:
#             cabin_number += i
#     return cabin_number

# %% [raw]
# df['Cabin'].apply(finding_cabin_name)

# %% [raw]
# # lets seperate them both
# df['cabin name']= df['Cabin'].apply(finding_cabin_name)

# %% [raw]
# df['cabin number'] =  df['Cabin'].apply(finding_cabin_number)

# %% [raw]
# df['cabin number'].unique()

# %% [raw]
# pd.pivot_table(data=df,index='cabin number',columns='Survived',aggfunc='count',values='PassengerId').reset_index().sort_values(by=1,ascending=False)

# %% [raw]
# pd.pivot_table(data=df,index='cabin name',columns='Survived',aggfunc='count',values='PassengerId')
