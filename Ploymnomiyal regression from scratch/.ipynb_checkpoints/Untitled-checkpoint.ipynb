# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as sk

# %%
# generating data
m = 100
x = 6*np.random.rand(m,1)-3
y = 0.5 * x**2 + x +2 + np.random.randn(m,1)

# %%
plt.scatter(x=x,y=y)
plt.show()

# %%
model = sk.preprocessing.PolynomialFeatures(degree=2,include_bias=False)

# %%
x_poly = model.fit_transform(x)

# %%
print(x[0])
print(x_poly[0])
# Out:
# [1.19756944]
# [1.19756944 1.43417256]

# %%
lr = sk.linear_model.LinearRegression()
lr_poly = sk.linear_model.LinearRegression()

# %%
lr.fit(x,y)
# Out:
# LinearRegression()

# %%
lr_poly.fit(x_poly,y)
# Out:
# LinearRegression()

# %%
intercept = lr.intercept_
coef = lr.coef_

# %%
print(intercept,coef)
# Out:
# [3.63684816] [[1.03652975]]

# %%
pred = coef*x+intercept

# %%
# ploting every thing
plt.scatter(x=x,y=y)
plt.plot(x,pred)

# %% [raw]
# import numpy as np
# import matplotlib.pyplot as plt
#
# # sample data
# X = np.array([1, 2, 3, 4, 5])
# y = np.array([2, 4, 5, 4, 6])
#
# # given regression parameters
# coef = 0.8        # slope
# intercept = 1.5  # intercept
#
# # scatter plot
# plt.scatter(X, y)
#
# # regression line
# y_pred = coef * X + intercept
# plt.plot(X, y_pred)
#
# plt.xlabel("X")
# plt.ylabel("y")
# plt.show()

# %%
plt.plot([1,2,3,4,5],[4,5,6,5,2])

# %%
import random
name = list('abcdefghijklmnopqrstuvwxyz')
nums = list(range(len(name)))
nums = [i+random.random()*2 for i in nums]
plt.plot(name,nums)
